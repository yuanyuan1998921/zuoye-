# %%
kaifang_file_path='C:\\Users\\Lucky\\Desktop\\kaifangX.txt'
email_file_path='C:\\Users\\Lucky\\Desktop\\python.txt'
kaifang_file=open(kaifang_file_path,'r',encoding='gbk',errors='ignore')
email_file=open(email_file_path,'a',encoding='utf-8',errors='ignore')
for i in range(10000):
    try:
        email=kaifang_file.readline(),split(',')[9]
        email_file.write(email)
    except Exception as e:
        print(e)
        print('未获取到数据')
kaifang_file.close()
email_file.close()
# Out:
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# name 'split' is not defined
# 未获取到数据
# ...

# %%
import requests
response=requests

# %%
import requests
response = requests.get('http://httpbin.org/get?name=joker&age=19')
print(response.text)
# Out:
# {"args":{"age":"19","name":"joker"},"headers":{"Accept":"*/*","Accept-Encoding":"gzip, deflate","Connection":"close","Host":"httpbin.org","User-Agent":"python-requests/2.18.4"},"origin":"123.178.75.242","url":"http://httpbin.org/get?name=joker&age=19"}

# %%
import requests
url = 'https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1529198575&di=c962e52755656507c7a1af8271dd446f&imgtype=jpg&er=1&src=http%3A%2F%2Fimg0.pclady.com.cn%2Fpclady%2F1806%2F08%2F1828307_03.jpg'
response=requests.get(url)
print(response.content)
with open('C:\\Users\\Lucky\\Desktop\\xiaogege.jpg','wb')as f:
    f.write(response.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x07\x05\x05\x06\x05\x04\x07\x06\x05\x06\x08\x07\x07\x08\n\x11\x0b\n\t\t\n\x15\x0f\x10\x0c\x11\x18\x15\x1a\x19\x18\x15\x18\x17\x1b\x1e\'!\x1b\x1d%\x1d\x17\x18"."%()+,+\x1a /3/*2\'*+*\xff\xdb\x00C\x01\x07\x08\x08\n\t\n\x14\x0b\x0b\x14*\x1c\x18\x1c**************************************************\xff\xc0\x00\x11\x08\x01\xad\x02U\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x01\x00\x01\x05\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x02\x03\x05\x06\x07\x01\x08\xff\xc4\x00Z\x10\x00\x02\x01\x03\x02\x03\x04\x04\x07\x0b\x07\t\x05\x06\x07\x00\x00\x01\x02\x03\x04\x11\x05!\x121A\x06\x13Qa\x07\x08"q\x142t\x81\x91\xb1\xb2\x15\x17\x1867BR\x94\xa1\xd2\xe2#$Te\xa4\xb3\xc1\x16\'34bdr\x84\xd1%DU\xe1\xf0&SV\x82\x92\xa25CEFs\xc2\xf1\xff\xc4\x00\x19\x01\x01\x00\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\xff\xc4\x00$\x11\x01\x01\x00\x02\x02\x02\x02\x03\x01\x01\x01
# ...

# %%
import requests
data{'name':'joker','age':'18',}
response=requests.get('http://httpbin.org/get',params=data)
print(response.text)
# Out:
#   File "<ipython-input-15-7fc23e01ef32>", line 2
#     data{'name':'joker','age':'18',}
#         ^
# SyntaxError: invalid syntax
